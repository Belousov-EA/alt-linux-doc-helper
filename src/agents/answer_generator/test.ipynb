# %%
import sys

sys.path.append("../../..")

# %%
from answer_generator import AnswerGeneratorSubgraphFabric

# %%
answer_generator_fabric = AnswerGeneratorSubgraphFabric()

# %%
subgraph = answer_generator_fabric.get_subgraph()

# %%
from langchain_core.messages import HumanMessage


message = HumanMessage(content="Tell me somthing")
subgraph.invoke({"messages": message, "docs": []})
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 5
#       1 from langchain_core.messages import HumanMessage
#       4 message = HumanMessage(content="Tell me somthing")
# ----> 5 subgraph.invoke({"messages": message, "docs": []})
#
# File c:\Users\Evgeny\Desktop\Сторонние проекты\pet_projects\alt-linux-doc-helper\alt-linux-doc-helper\.venv\Lib\site-packages\langgraph\pregel\__init__.py:2669, in Pregel.invoke(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, debug, **kwargs)
#    2667 else:
#    2668     chunks = []
# -> 2669 for chunk in self.stream(
#    2670     input,
#    2671     config,
#    2672     stream_mode=stream_mode,
#    2673     output_keys=output_keys,
#    2674     interrupt_before=interrupt_before,
#    2675     interrupt_after=interrupt_after,
#    2676     debug=debug,
#    2677     **kwargs,
#    2678 ):
# ...

# %%
import sys

sys.path.append("../../..")
from src.utils.yaml_reader import read_yaml
from src.utils.project_path import Project


yaml = read_yaml(Project.ANSWER_GENERATOR_AGENT / "answer_generator.yaml")
yaml
# Out:
# {'model': 'qwen2.5:32b',
#  'system_prompt': "You are the best in the worl base-linux consultant. You must unswer on client's question aboout base-linux. Use base-linux documentation for answering. Base-linux documentation: {docs}"}

# %%
yaml["system_prompt"].format(docs="TEST")
# Out:
# "You are the best in the worl base-linux consultant. You must unswer on client's question aboout base-linux. Use base-linux documentation for answering. Base-linux documentation: TEST"
